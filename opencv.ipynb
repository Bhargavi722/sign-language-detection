# %%
import cv2
from matplotlib import pyplot as plt

# %%
img1 = cv2.imread("Resource/x.jpg")

# %%
img = cv2.resize(img1, (224, 224))

# %%
plt.imshow(cv2.cvtColor(img1,cv2.COLOR_BGR2RGB))
plt.imshow(img)

# %%
img2 = cv2.imread("Resource/9.jpg")

# %%
result=img1+img2
plt.imshow(result)

# %%
img2 = cv2.imread("Resource/v.jpg")

# %%
result=img1-img2

# %%
plt.imshow(result)

# %%
result=img1*img2
plt.imshow(result)

# %%
result=img1/img2
plt.imshow(result)
# Out:
# C:\Users\gowda\AppData\Local\Temp\ipykernel_54064\1580248168.py:1: RuntimeWarning: divide by zero encountered in divide
#   result=img1/img2
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..127.5].

# %%
img1=cv2.imread("Resource/v.JPG")
img=cv2.cvtColor(img1,cv2.COLOR_BGR2HSV)
figure_size=7
result=cv2.blur(img,(figure_size,figure_size))
plt.figure(figsize=(11,6))
plt.subplot(121),plt.imshow(cv2.cvtColor(img,cv2.COLOR_HSV2RGB)),plt.title("Original")
plt.xticks([]),plt.yticks([])
plt.subplot(122),plt.imshow(cv2.cvtColor(result,cv2.COLOR_HSV2RGB)),plt.title("Blurred")
plt.xticks([]),plt.yticks([])
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img1=cv2.imread("Resource/v.jpg")

# %%
(height,width)=img.shape[0:2]
zoom=cv2.resize(img,None,fx=1.5,fy=1.5,interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
zoom=cv2.resize(img,(int(width*2),int(height*2)),interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
m=cv2.getRotationMatrix2D((width/2,height/2),30,1)
rotate=cv2.warpAffine(img,m,(height,width))
plt.imshow(rotate)

# %%
import numpy as np

# %%
m=np.float32([[1,0,50],[0,1,100]])
dst=cv2.warpAffine(img,m,(height,width))
plt.imshow(dst)
